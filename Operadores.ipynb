# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrickCalorioCarvalho/CA020OBLinguagensDeProgramacao202601/blob/main/Operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
peso1 = '80.68'
peso1 = round(float(peso1),1)
peso2 = math.trunc(peso1)
print(f'{peso1}, {peso2} e {peso1:.3f}')
# Out:
# 80.7, 80 e 80.700

# %%
A = True
B = False
C = A or B
D = A and B
E = not(B)
print(f'{C}, {D} e {E}')
# Out:
# True, False e True

# %%
temperatura = 27
if temperatura < 0:
  print('Muito Frio')
elif temperatura < 15:
  print('Frio')
elif temperatura < 27:
  print('Calor')
else:
  print('Muito Calor')
# Out:
# Muito Calor

# %%
import math
distancia = '90.4734'
distancia1 = round(float(distancia),2)
distancia2 = math.trunc(distancia1)
distancia3 = math.ceil(distancia1)
distancia4 = math.floor(distancia1)

print(f'{distancia1}, {distancia2}, {distancia3} e {distancia4}')
# Out:
# 90.47, 90, 91 e 90

# %%
idade = int(input('Qual e sua idade:'))

if idade >= 18:
  print('Entra Liberada')
else:
  print('Entrada BLoqueada porem')
  esta_com_pais = input("Ta acompanahdos dos Pais (s/n)").strip().lower() == 's'
  if esta_com_pais:
    print("Liberado com os Pais")
  else:
    print("Infelismente nao pode entrar")
# Out:
# Qual e sua idade:17
# Entrada BLoqueada porem
# Ta acompanahdos dos Pais (s/n)N
# Infelismente nao pode entrar

# %%
possui_convite =  input("Tem Convite (s/n)").strip().lower()
esta_na_lista =  input("Ta na Lista (s/n)").strip().lower()
if possui_convite == 's' or esta_na_lista == 's':
  print('Entra Liberada')
else:
  print("Infelismente nao pode entrar")
# Out:
# Tem Convite (s/n)s
# Ta na Lista (s/n)S
# Entra Liberada
