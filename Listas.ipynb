# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrickCalorioCarvalho/CA020OBLinguagensDeProgramacao202601/blob/main/Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = [8.5,5,'txt',True,'x']
print(f'{type(L[0])},{type(L[1])},{type(L[2])},{type(L[3])},{type(L[4])}')
# Out:
# <class 'float'>,<class 'int'>,<class 'str'>,<class 'bool'>,<class 'str'>

# %%
aluno = ['Pedro',20,8.5,'Londrina']
print(aluno[1])
# Out:
# 20

# %%
cursos = ['python','java','c++','pascal']
curso_escolhido = input("Digite o nome do curso que voce deseja se inscrever: ").lower()

if curos_escolhido in cursos:
  print(f'O curso {curso_escolhido} esta disponivel para inscricao')
else:
  print(f'O curso {curso_escolhido} nao esta disponivel no momento')
# Out:
# Digite o nome do curso que voce deseja se inscrever: python
# O curso python nao esta disponivel no momento

# %%
L = [5,10,15,20]
print(12 in L)
# Out:
# False

# %%
L = [5,10,15,20,25,30]
L.reverse()
print(L)
# Out:
# [30, 25, 20, 15, 10, 5]

# %%
L=[['A','B','C'],['D','E','F','H']]
print(L[1][1])
# Out:
# E
