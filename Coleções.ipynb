# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrickCalorioCarvalho/CA020OBLinguagensDeProgramacao202601/blob/main/Cole%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
disciplinas1 = ('Matematica','Historia')
disciplinas2 = ('Portugues','Ciencias')
disciplinas3 = ('Geografia','Artes')
materias = disciplinas1+disciplinas3+disciplinas2
print(materias)
# Out:
# ('Matematica', 'Historia', 'Geografia', 'Artes', 'Portugues', 'Ciencias')

# %%
T = (5,'Python',3.14,True)
T = T + (False,[1,2])
print(T)
# Out:
# (5, 'Python', 3.14, True, False, [1, 2])

# %%
a = {1,2,3,4,5,6}
b = {3,6,9}
c = a.intersection(b)
print(c)
# Out:
# {3, 6}

# %%
a = {1,2,3,4,5,6}
a.add(6)
a.add(7)
a.add(8)
a.add(9)
print(a)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
estoque_frutas = {
    'M':15,
    'B':8,
    'L':12,
    'U':10
}
print('Quantidade disponivel em estoque:')
for quantidade in estoque_frutas.values():
  print(f'Quantidades: {quantidade}')
# Out:
# Quantidade disponivel em estoque:
# Quantidades: 15
# Quantidades: 8
# Quantidades: 12
# Quantidades: 10

# %%
D = {
    'Nome':'Carlos',
    'Idade':42,
    'Profissoa':'Advogado',
    'Contratado':True
}
print(D.values())
# Out:
# dict_values(['Carlos', 42, 'Advogado', True])
