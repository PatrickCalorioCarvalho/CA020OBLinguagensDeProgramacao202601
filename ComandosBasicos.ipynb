# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrickCalorioCarvalho/CA020OBLinguagensDeProgramacao202601/blob/main/ComandosBasicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Tenham um bom dia')
# Out:
# Tenham um bom dia

# %%
cidade = input('Qual o nome da sua cidade?')
print(f'o nome da minha cidade e {cidade}')
# Out:
# Qual o nome da sua cidade?adamantina
# o nome da minha cidade e adamantina

# %%
A = 6
B = 4
C = 2
R = A + B * C
S = A / B + C
print(f'{R} e {S}')
# Out:
# 14 e 3.5

# %%
valor_hora = 10
nome = 'Laura'
horas_trabalhadas = 40
salario = valor_hora * horas_trabalhadas
print(f'{nome} trabalho {horas_trabalhadas} e recebeu R${salario:.2f}')
# Out:
# Laura trabalho 40 e recebeu R$400.00

# %%
a = 45.5
b = 4
c = float(5)
d = True
e = 'Bom dia'

print(f'{type(a)},{type(b)},{type(c)},{type(d)},{type(e)}')
# Out:
# <class 'float'>,<class 'int'>,<class 'float'>,<class 'bool'>,<class 'str'>

# %%
A = 4
B = 2

C = A ** B
D = A / B
E = A % B

print(f'{C}, {D} e {E}')
# Out:
# 16, 2.0 e 0
