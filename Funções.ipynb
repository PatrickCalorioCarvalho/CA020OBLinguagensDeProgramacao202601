# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrickCalorioCarvalho/CA020OBLinguagensDeProgramacao202601/blob/main/Fun%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def funcao(lista,valor):
  return lista.count(valor)

numeros = [2,4,6,2,8,4,2,7]
print(funcao(numeros,2))
# Out:
# 3

# %%
def valores():
    return 1, 2, 3

print(valores())
# Out:
# (1, 2, 3)

# %%
def soma(X, Y):
  R = X + Y
  return R

a = 'A'
b = 'B'
s = soma(a, b)
a = 2
b = 4
s1 = soma(a, b)
print(f'{s} {s1}')
# Out:
# AB 6

# %%
def Soma(a, b):
  x = a + b
  y = b - a
  print(x)
  print(y)
  return x

a = 3
b = 5

x = b - a
s = soma(a, b)
print(f'x = {x} e y = {y}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22895/583046026.py in <cell line: 0>()
#      11 x = b - a
#      12 s = soma(a, b)
# ---> 13 print(f'x = {x} e y = {y}')
#
# NameError: name 'y' is not defined

# %%
def Concatena(A,B,C):
  return A + B + C

def Entradas():
  a = 'X'
  b = 'Y'
  c = 'Z'
  Res = Concatena(a,b,c)
  return Res

s = Entradas()

print(f'Resutlado = {s}')
# Out:
# Resutlado = XYZ

# %%
def perfil_pessoa(nome, idade):
    letras_nome = len(nome)
    maiusculo = nome.upper()
    maior_idade = idade >= 18
    return nome, maiusculo, letras_nome, maior_idade

nome = 'Silvio'
idade = 49

resultado = perfil_pessoa(nome, idade)

print(f"{resultado[0]}, {resultado[1]}, {resultado[2]}, {resultado[3]}")
# Out:
# Silvio, SILVIO, 6, True
