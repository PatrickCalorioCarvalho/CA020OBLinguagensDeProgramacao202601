# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrickCalorioCarvalho/CA020OBLinguagensDeProgramacao202601/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frase = "UTFPR"

print(frase[::2])
print(frase[::-1])
print(frase[0:3])
# Out:
# UFR
# RPFTU
# UTF

# %%
S = 'linguagem de programacao python'
print(S.swapcase())
print(S.title())
print(S.lower())
print(S.upper())
print(S.capitalize())
# Out:
# LINGUAGEM DE PROGRAMACAO PYTHON
# Linguagem De Programacao Python
# linguagem de programacao python
# LINGUAGEM DE PROGRAMACAO PYTHON
# Linguagem de programacao python

# %%
nome = 'Paulo'
saudacao = 'Tenha um bom dia'
saida = 'Ola, ' + nome + '. ' + saudacao + '!'
print(saida)
# Out:
# Ola, Paulo. Tenha um bom dia!

# %%
D = 'Texto'
print(f'({len(D)}) ({D[0]}) ({D[-1]})')
# Out:
# (5) (T) (o)

# %%
S = 'Universidade Tecnologica Federal do Parana'
print(S[13:])
print(S[13:24])
print(f'{S[0]}{S[13]}{S[25]}{S[36]}{S[38].upper()}')
# Out:
# Tecnologica Federal do Parana
# Tecnologica
# UTFPR

# %%
S = 'Sou estudante da Universidade Tecnologica Federal do Parana'
T = S.replace('Universidade Tecnologica Federal do Parana','UTFPR')
print(T)
# Out:
# Sou estudante da UTFPR
